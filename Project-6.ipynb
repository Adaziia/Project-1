# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("daibetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
import scipy.cluster.hierarchy as sch
plt.title("Dendrogram of the Daibetes dataset")
dendrogram=sch.dendrogram(sch.linkage(data,method="ward"))

# %%
df=pd.read_csv("3.01.Country. cluster.csv")

# %%
df.head()
# Out:
#    Country  Latitude  Longitude Language
# 0      USA     44.97    -103.77  English
# 1   Canada     62.40     -96.80  English
# 2   France     46.75       2.40   French
# 3       UK     54.01      -2.53  English
# 4  Germany     51.15      10.40   German

# %%
df1=df.iloc[:,1:3]

# %%
df1.head()
# Out:
#    Latitude  Longitude
# 0     44.97    -103.77
# 1     62.40     -96.80
# 2     46.75       2.40
# 3     54.01      -2.53
# 4     51.15      10.40

# %%
plt.title("Dendrogram of the Country dataset")
dendrogram=sch.dendrogram(sch.linkage(df1,method="ward"))

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()

# %%
df["Country"].unique()
# Out:
# array(['USA', 'Canada', 'France', 'UK', 'Germany', 'Australia'],
#       dtype=object)

# %%
df["Country"]=label_encoder.fit_transform(df["Country"])
df["Country"].unique()
# Out:
# array([5, 1, 2, 4, 3, 0])

# %%
df["Language"].unique()
# Out:
# array(['English', 'French', 'German'], dtype=object)

# %%
df["Lan

# %%
from sklearn.cluster import KMeans
kmeans=KMeans(3)

# %%
kmeans.fit(df)

# %%
clusters=kmeans.fit_predict(df1)
